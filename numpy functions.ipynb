# %%
import numpy as np

# %%
a=np.array([[1,8,3],[5,6,7]])
print(a.shape)
# Out:
# (2, 3)

# %%
b=np.array([1,2,3,5,7])
print(a.ndim)
# Out:
# 2

# %%
print(b.dtype)
# Out:
# int64

# %%
print(a[1,1])
# Out:
# 6

# %%
r=np.arange(0,10,2)
print(r[1:16])
# Out:
# [2 4 6 8]

# %%
print(a+5)
# Out:
# [[ 6 13  8]
#  [10 11 12]]

# %%
print(a*2)
# Out:
# [[ 2 16  6]
#  [10 12 14]]

# %%
print(a+b[0])
# Out:
# [[2 9 4]
#  [6 7 8]]

# %%
print(np.dot(b,b))
# Out:
# 88

# %%
print(np.sum(a))
# Out:
# 30

# %%
print(np.mean(b))
# Out:
# 3.6

# %%
print(np.sqrt(b))
# Out:
# [1.         1.41421356 1.73205081 2.23606798 2.64575131]

# %%
x=np.arange(8).reshape(4,2)
print(x.T)
# Out:
# [[0 2 4 6]
#  [1 3 5 7]]

# %%
df.read
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 df.read
#
# NameError: name 'df' is not defined
